# %%
import numpy as np
import pandas as pd #import pandas
calendar_df=pd.read_csv('/Users/carol/Desktop/calendar.csv') #read data from csv
calendar_df #show the data
# Out:
#          listing_id        date available price
# 0          12147973  2017-09-05         f   NaN
# 1          12147973  2017-09-04         f   NaN
# 2          12147973  2017-09-03         f   NaN
# 3          12147973  2017-09-02         f   NaN
# 4          12147973  2017-09-01         f   NaN
# ...             ...         ...       ...   ...
# 1308885    14504422  2016-09-10         f   NaN
# 1308886    14504422  2016-09-09         f   NaN
# 1308887    14504422  2016-09-08         f   NaN
# 1308888    14504422  2016-09-07         f   NaN
# 1308889    14504422  2016-09-06         f   NaN
#
# [1308890 rows x 4 columns]

# %%
listings_df=pd.read_csv('/Users/carol/Desktop/listings.csv') #read data from csv
listings_df #show the data
# Out:
#       listing_id                            listing_url     scrape_id  \
# 0       12147973  https://www.airbnb.com/rooms/12147973  2.020000e+13
# 1        3075044   https://www.airbnb.com/rooms/3075044  2.020000e+13
# 2           6976      https://www.airbnb.com/rooms/6976  2.020000e+13
# 3        1436513   https://www.airbnb.com/rooms/1436513  2.020000e+13
# 4        7651065   https://www.airbnb.com/rooms/7651065  2.020000e+13
# ...          ...                                    ...           ...
# 3580     8373729   https://www.airbnb.com/rooms/8373729  2.020000e+13
# 3581    14844274  https://www.airbnb.com/rooms/14844274  2.020000e+13
# 3582    14585486  https://www.airbnb.com/rooms/14585486  2.020000e+13
# 3583    14603878  https://www.airbnb.com/rooms/14603878  2.020000e+13
# 3584    14504422  https://www.airbnb.com/rooms/14504422  2.020000e+13
#
#      last_scraped                                           name  \
# ...

# %%
#Q1
import math
listings_df['host_response_rate']=listings_df['host_response_rate'].apply(str)
listm=[]
for i in (listings_df['host_response_rate']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', ''))/100)
listings_df['host_response_rate']=listm
a1=listings_df['host_response_rate'].mean()
a2=listings_df['host_response_rate'].median()
a3=listings_df['host_response_rate'].max()
a4=listings_df['host_response_rate'].min()
a5=np.nanvar(np.array(listings_df['host_response_rate']))
a6=math.sqrt(np.nanvar(np.array(listings_df['host_response_rate'])))

# %%
import math
listings_df['host_acceptance_rate']=listings_df['host_acceptance_rate'].apply(str)
listm=[]
for i in (listings_df['host_acceptance_rate']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', ''))/100)
listings_df['host_acceptance_rate']=listm
b1=listings_df['host_acceptance_rate'].mean()
b2=listings_df['host_acceptance_rate'].median()
b3=listings_df['host_acceptance_rate'].max()
b4=listings_df['host_acceptance_rate'].min()
b5=np.nanvar(np.array(listings_df['host_acceptance_rate']))
b6=math.sqrt(np.nanvar(np.array(listings_df['host_acceptance_rate'])))

# %%
listings_df['host_listings_count'].isnull().sum()
# Out:
# 0

# %%
import statistics
def variance(dat):
    return statistics.variance(dat)
def std_dev(dat):
    return statistics.stdev(dat)
c1=listings_df['host_listings_count'].mean()
c2=listings_df['host_listings_count'].median()
c3=listings_df['host_listings_count'].max()
c4=listings_df['host_listings_count'].min()
c5=variance(listings_df['host_listings_count'])
c6=std_dev(listings_df['host_listings_count'])

# %%
listings_df['host_total_listings_count'].isnull().sum()
# Out:
# 0

# %%
d1=listings_df['host_total_listings_count'].mean()
d2=listings_df['host_total_listings_count'].median()
d3=listings_df['host_total_listings_count'].max()
d4=listings_df['host_total_listings_count'].min()
d5=variance(listings_df['host_total_listings_count'])
d6=std_dev(listings_df['host_total_listings_count'])

# %%
listings_df['accommodates'].isnull().sum()
# Out:
# 0

# %%
e1=listings_df['accommodates'].mean()
e2=listings_df['accommodates'].median()
e3=listings_df['accommodates'].max()
e4=listings_df['accommodates'].min()
e5=variance(listings_df['accommodates'])
e6=std_dev(listings_df['accommodates'])

# %%
listings_df['bathrooms'].isnull().sum()
# Out:
# 14

# %%
f1=listings_df['bathrooms'].mean()
f2=listings_df['bathrooms'].median()
f3=listings_df['bathrooms'].max()
f4=listings_df['bathrooms'].min()
f5=np.nanvar(np.array(listings_df['bathrooms']))
f6=math.sqrt(np.nanvar(np.array(listings_df['bathrooms'])))

# %%
listings_df['bedrooms'].isnull().sum()
# Out:
# 10

# %%
g1=listings_df['bedrooms'].mean()
g2=listings_df['bedrooms'].median()
g3=listings_df['bedrooms'].max()
g4=listings_df['bedrooms'].min()
g5=np.nanvar(np.array(listings_df['bedrooms']))
g6=math.sqrt(np.nanvar(np.array(listings_df['bedrooms'])))

# %%
listings_df['beds'].isnull().sum()
# Out:
# 9

# %%
listings_df['beds'].fillna(listings_df['beds'].mean(), inplace=True)
h1=listings_df['beds'].mean()
h2=listings_df['beds'].median()
h3=listings_df['beds'].max()
h4=listings_df['beds'].min()
h5=np.nanvar(np.array(listings_df['beds']))
h6=math.sqrt(np.nanvar(np.array(listings_df['beds'])))

# %%
listings_df['price']
# Out:
# 0       $250.00
# 1        $65.00
# 2        $65.00
# 3        $75.00
# 4        $79.00
#           ...
# 3580     $69.00
# 3581    $150.00
# 3582    $198.00
# 3583     $65.00
# 3584     $65.00
# Name: price, Length: 3585, dtype: object

# %%
import math
listings_df['price']=listings_df['price'].apply(str)
listm=[]
for i in (listings_df['price']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['price']=listm
i1=listings_df['price'].mean()
i2=listings_df['price'].median()
i3=listings_df['price'].max()
i4=listings_df['price'].min()
i5=np.nanvar(np.array(listings_df['price']))
i6=math.sqrt(np.nanvar(np.array(listings_df['price'])))

# %%
listings_df['weekly_price']
# Out:
# 0            NaN
# 1       $400.00
# 2       $395.00
# 3            NaN
# 4            NaN
#           ...
# 3580         NaN
# 3581         NaN
# 3582         NaN
# 3583         NaN
# 3584         NaN
# Name: weekly_price, Length: 3585, dtype: object

# %%
import math
listings_df['weekly_price']=listings_df['weekly_price'].apply(str)
listm=[]
for i in (listings_df['weekly_price']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['weekly_price']=listm
j1=listings_df['weekly_price'].mean()
j2=listings_df['weekly_price'].median()
j3=listings_df['weekly_price'].max()
j4=listings_df['weekly_price'].min()
j5=np.nanvar(np.array(listings_df['weekly_price']))
j6=math.sqrt(np.nanvar(np.array(listings_df['weekly_price'])))

# %%
listings_df['monthly_price']
# Out:
# 0              NaN
# 1              NaN
# 2       $1,350.00
# 3              NaN
# 4              NaN
#            ...
# 3580           NaN
# 3581           NaN
# 3582           NaN
# 3583           NaN
# 3584           NaN
# Name: monthly_price, Length: 3585, dtype: object

# %%
import math
listings_df['monthly_price']=listings_df['monthly_price'].apply(str)
listm=[]
for i in (listings_df['monthly_price']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['monthly_price']=listm
k1=listings_df['monthly_price'].mean()
k2=listings_df['monthly_price'].median()
k3=listings_df['monthly_price'].max()
k4=listings_df['monthly_price'].min()
k5=np.nanvar(np.array(listings_df['monthly_price']))
k6=math.sqrt(np.nanvar(np.array(listings_df['monthly_price'])))

# %%
listings_df['security_deposit']
# Out:
# 0            NaN
# 1        $95.00
# 2            NaN
# 3       $100.00
# 4            NaN
#           ...
# 3580     $95.00
# 3581    $100.00
# 3582         NaN
# 3583    $100.00
# 3584         NaN
# Name: security_deposit, Length: 3585, dtype: object

# %%
import math
listings_df['security_deposit']=listings_df['security_deposit'].apply(str)
listm=[]
for i in (listings_df['security_deposit']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['security_deposit']=listm
l1=listings_df['security_deposit'].mean()
l2=listings_df['security_deposit'].median()
l3=listings_df['security_deposit'].max()
l4=listings_df['security_deposit'].min()
l5=np.nanvar(np.array(listings_df['security_deposit']))
l6=math.sqrt(np.nanvar(np.array(listings_df['security_deposit'])))

# %%
listings_df['cleaning_fee']
# Out:
# 0       $35.00
# 1       $10.00
# 2           NaN
# 3       $50.00
# 4       $15.00
#          ...
# 3580        NaN
# 3581    $15.00
# 3582        NaN
# 3583        NaN
# 3584    $25.00
# Name: cleaning_fee, Length: 3585, dtype: object

# %%
import math
listings_df['cleaning_fee']=listings_df['cleaning_fee'].apply(str)
listm=[]
for i in (listings_df['cleaning_fee']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['cleaning_fee']=listm
m1=listings_df['cleaning_fee'].mean()
m2=listings_df['cleaning_fee'].median()
m3=listings_df['cleaning_fee'].max()
m4=listings_df['cleaning_fee'].min()
m5=np.nanvar(np.array(listings_df['cleaning_fee']))
m6=math.sqrt(np.nanvar(np.array(listings_df['cleaning_fee'])))

# %%
listings_df['guests_included'].isnull().sum()
# Out:
# 0

# %%
n1=listings_df['guests_included'].mean()
n2=listings_df['guests_included'].median()
n3=listings_df['guests_included'].max()
n4=listings_df['guests_included'].min()
n5=variance(listings_df['guests_included'])
n6=std_dev(listings_df['guests_included'])

# %%
listings_df['extra_people']
# Out:
# 0        $0.00
# 1        $0.00
# 2       $20.00
# 3       $25.00
# 4        $0.00
#          ...
# 3580    $24.00
# 3581     $0.00
# 3582     $0.00
# 3583    $30.00
# 3584    $30.00
# Name: extra_people, Length: 3585, dtype: object

# %%
import math
listings_df['extra_people']=listings_df['extra_people'].apply(str)
listm=[]
for i in (listings_df['extra_people']):
    listm.append(float(i.replace('%', '').replace('$', '').replace(',', '')))
listings_df['extra_people']=listm
o1=listings_df['extra_people'].mean()
o2=listings_df['extra_people'].median()
o3=listings_df['extra_people'].max()
o4=listings_df['extra_people'].min()
o5=np.nanvar(np.array(listings_df['extra_people']))
o6=math.sqrt(np.nanvar(np.array(listings_df['extra_people'])))

# %%
listings_df['minimum_nights'].isnull().sum()
# Out:
# 0

# %%
p1=listings_df['minimum_nights'].mean()
p2=listings_df['minimum_nights'].median()
p3=listings_df['minimum_nights'].max()
p4=listings_df['minimum_nights'].min()
p5=variance(listings_df['minimum_nights'])
p6=std_dev(listings_df['minimum_nights'])

# %%
listings_df['maximum_nights'].isnull().sum()
# Out:
# 0

# %%
q1=listings_df['maximum_nights'].mean()
q2=listings_df['maximum_nights'].median()
q3=listings_df['maximum_nights'].max()
q4=listings_df['maximum_nights'].min()
q5=variance(listings_df['maximum_nights'])
q6=std_dev(listings_df['maximum_nights'])

# %%
listings_df['availability_30'].isnull().sum()
# Out:
# 0

# %%
r1=listings_df['availability_30'].mean()
r2=listings_df['availability_30'].median()
r3=listings_df['availability_30'].max()
r4=listings_df['availability_30'].min()
r5=variance(listings_df['availability_30'])
r6=std_dev(listings_df['availability_30'])

# %%
listings_df['availability_90'].isnull().sum()
# Out:
# 0

# %%
s1=listings_df['availability_90'].mean()
s2=listings_df['availability_90'].median()
s3=listings_df['availability_90'].max()
s4=listings_df['availability_90'].min()
s5=variance(listings_df['availability_90'])
s6=std_dev(listings_df['availability_90'])

# %%
listings_df['availability_365'].isnull().sum()
# Out:
# 0

# %%
t1=listings_df['availability_365'].mean()
t2=listings_df['availability_365'].median()
t3=listings_df['availability_365'].max()
t4=listings_df['availability_365'].min()
t5=variance(listings_df['availability_365'])
t6=std_dev(listings_df['availability_365'])

# %%
listings_df['number_of_reviews'].isnull().sum()
# Out:
# 0

# %%
u1=listings_df['number_of_reviews'].mean()
u2=listings_df['number_of_reviews'].median()
u3=listings_df['number_of_reviews'].max()
u4=listings_df['number_of_reviews'].min()
u5=variance(listings_df['number_of_reviews'])
u6=std_dev(listings_df['number_of_reviews'])

# %%
listings_df['review_scores_rating']
# Out:
# 0         NaN
# 1        94.0
# 2        98.0
# 3       100.0
# 4        99.0
#         ...
# 3580     90.0
# 3581      NaN
# 3582      NaN
# 3583     90.0
# 3584      NaN
# Name: review_scores_rating, Length: 3585, dtype: float64

# %%
v1=listings_df['review_scores_rating'].mean()
v2=listings_df['review_scores_rating'].median()
v3=listings_df['review_scores_rating'].max()
v4=listings_df['review_scores_rating'].min()
v5=np.nanvar(np.array(listings_df['review_scores_rating']))
v6=math.sqrt(np.nanvar(np.array(listings_df['review_scores_rating'])))

# %%
listings_df['review_scores_accuracy']
# Out:
# 0        NaN
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
#         ...
# 3580    10.0
# 3581     NaN
# 3582     NaN
# 3583     9.0
# 3584     NaN
# Name: review_scores_accuracy, Length: 3585, dtype: float64

# %%
w1=listings_df['review_scores_accuracy'].mean()
w2=listings_df['review_scores_accuracy'].median()
w3=listings_df['review_scores_accuracy'].max()
w4=listings_df['review_scores_accuracy'].min()
w5=np.nanvar(np.array(listings_df['review_scores_accuracy']))
w6=math.sqrt(np.nanvar(np.array(listings_df['review_scores_accuracy'])))

# %%
listings_df['review_scores_cleanliness']
# Out:
# 0        NaN
# 1        9.0
# 2        9.0
# 3       10.0
# 4       10.0
#         ...
# 3580    10.0
# 3581     NaN
# 3582     NaN
# 3583     8.0
# 3584     NaN
# Name: review_scores_cleanliness, Length: 3585, dtype: float64

# %%
x1=listings_df['review_scores_cleanliness'].mean()
x2=listings_df['review_scores_cleanliness'].median()
x3=listings_df['review_scores_cleanliness'].max()
x4=listings_df['review_scores_cleanliness'].min()
x5=np.nanvar(np.array(listings_df['review_scores_cleanliness']))
x6=math.sqrt(np.nanvar(np.array(listings_df['review_scores_cleanliness'])))

# %%
listings_df['review_scores_checkin']
# Out:
# 0        NaN
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
#         ...
# 3580    10.0
# 3581     NaN
# 3582     NaN
# 3583     9.0
# 3584     NaN
# Name: review_scores_checkin, Length: 3585, dtype: float64

# %%
y1=listings_df['review_scores_checkin'].mean()
y2=listings_df['review_scores_checkin'].median()
y3=listings_df['review_scores_checkin'].max()
y4=listings_df['review_scores_checkin'].min()
y5=np.nanvar(np.array(listings_df['review_scores_checkin']))
y6=math.sqrt(np.nanvar(np.array(listings_df['review_scores_checkin'])))

# %%
listings_df['review_scores_communication']
# Out:
# 0        NaN
# 1       10.0
# 2       10.0
# 3       10.0
# 4       10.0
#         ...
# 3580    10.0
# 3581     NaN
# 3582     NaN
# 3583     9.0
# 3584     NaN
# Name: review_scores_communication, Length: 3585, dtype: float64

# %%
z1=listings_df['review_scores_communication'].mean()
z2=listings_df['review_scores_communication'].median()
z3=listings_df['review_scores_communication'].max()
z4=listings_df['review_scores_communication'].min()
z5=np.nanvar(np.array(listings_df['review_scores_communication']))
z6=math.sqrt(np.nanvar(np.array(listings_df['review_scores_communication'])))

# %%
listings_df['review_scores_value']
# Out:
# 0        NaN
# 1        9.0
# 2       10.0
# 3       10.0
# 4       10.0
#         ...
# 3580     9.0
# 3581     NaN
# 3582     NaN
# 3583     7.0
# 3584     NaN
# Name: review_scores_value, Length: 3585, dtype: float64

# %%
z01=listings_df['review_scores_value'].mean()
z02=listings_df['review_scores_value'].median()
z03=listings_df['review_scores_value'].max()
z04=listings_df['review_scores_value'].min()
z05=np.nanvar(np.array(listings_df['review_scores_value']))
z06=math.sqrt(np.nanvar(np.array(listings_df['review_scores_value'])))

# %%
listings_df['reviews_per_month']
# Out:
# 0        NaN
# 1       1.30
# 2       0.47
# 3       1.00
# 4       2.25
#         ...
# 3580    0.34
# 3581     NaN
# 3582     NaN
# 3583    2.00
# 3584     NaN
# Name: reviews_per_month, Length: 3585, dtype: float64

# %%
z11=listings_df['reviews_per_month'].mean()
z12=listings_df['reviews_per_month'].median()
z13=listings_df['reviews_per_month'].max()
z14=listings_df['reviews_per_month'].min()
z15=np.nanvar(np.array(listings_df['reviews_per_month']))
z16=math.sqrt(np.nanvar(np.array(listings_df['reviews_per_month'])))

# %%
pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from prettytable import PrettyTable 
  
# Specify the Column Names while initializing the Table 
myTable = PrettyTable(["Variables", "Minimum", "Maximum", "Mean", "Median", "Variance", "Std. Deviation"]) 
  
# Add rows 
myTable.add_row(["host_response_rate", a4, a3, a1, a2, a5, a6]) 
myTable.add_row(["host_acceptance_rate", b4,b3,b1,b2,b5,b6]) 
myTable.add_row(["host_listings_count", c4,c3,c1,c2,c5,c6]) 
myTable.add_row(["host_total_listings_count",d4,d3,d1,d2,d5,d6]) 
myTable.add_row(["accommodates", e4,e3,e1,e2,e5,e6]) 
myTable.add_row(["bathrooms", f4,f3,f1,f2,f5,f6]) 
myTable.add_row(["bedrooms", g4,g3,g1,g2,g5,g6]) 
myTable.add_row(["beds", h4,h3,h1,h2,h5,h6]) 
myTable.add_row(["price", i4,i3,i1,i2,i5,i6]) 
myTable.add_row(["weekly_price", j4,j3,j1,j2,j5,j6]) 
myTable.add_row(["monthly_price", k4,k3,k1,k2,k5,k6]) 
myTable.add_row(["security_deposit", l4,l3,l1,l2,l5,l6]) 
myTable.add_row(["cleaning_fee", m4,m3,m1,m2,m5,m6]) 
myTable.add_row(["guests_included", n4,n3,n1,n2,n5,n6]) 
myTable.add_row(["extra_people", o4,o3,o1,o2,o5,o6]) 
myTable.add_row(["minimum_nights", p4,p3,p1,p2,p5,p6])
myTable.add_row(["maximum_nights", q4,q3,q1,q2,q5,q6])
myTable.add_row(["availability_30", r4,r3,r1,r2,r5,r6])
myTable.add_row(["availability_90", s4,s3,s1,s2,s5,s6])
myTable.add_row(["availability_365", t4,t3,t1,t2,t5,t6])
myTable.add_row(["number_of_reviews", u4,u3,u1,u2,u5,u6])
myTable.add_row(["review_scores_rating", v4,v3,v1,v2,v5,v6])
myTable.add_row(["review_scores_accuracy", w4,w3,w1,w2,w5,w6])
myTable.add_row(["review_scores_cleanliness", x4,x3,x1,x2,x5,x6])
myTable.add_row(["review_scores_checkin", y4,y3,y1,y2,y5,y6])
myTable.add_row(["review_scores_communication", z4,z3,z1,z2,z5,z6])
myTable.add_row(["review_scores_value", z04,z03,z01,z02,z05,z06])
myTable.add_row(["reviews_per_month", z14,z13,z11,z12,z15,z16])
print(myTable)
# Out:
# +-----------------------------+---------+----------+--------------------+--------+----------------------+---------------------+
# |          Variables          | Minimum | Maximum  |        Mean        | Median |       Variance       |    Std. Deviation   |
# +-----------------------------+---------+----------+--------------------+--------+----------------------+---------------------+
# |      host_response_rate     |   0.0   |   1.0    | 0.9498908156711676 |  1.0   | 0.015664214154569103 | 0.12515675832558584 |
# |     host_acceptance_rate    |   0.0   |   1.0    | 0.8417308927424536 |  0.94  | 0.047418359180513216 |  0.2177575697433116 |
# |     host_listings_count     |    0    |   749    |  58.9023709902371  |  2.0   |   29281.9391266313   |    171.1196631794   |
# |  host_total_listings_count  |    0    |   749    |  58.9023709902371  |  2.0   |   29281.9391266313   |    171.1196631794   |
# ...

# %%
#There are many missing data. Something strange is that the differences of variance between the variables are huge. Some data like maximum_nights, host_listings_count, host_total_listings_count, price, weekly_price, monthly_price have extremely large variance and standard deviation. Thus, these data are more likely to be badly measured compared with the data with small variance like host_response_rate and host_acceptance_rate with variance less than 0.05. 
#An obvious contrast here is the variance of minimum_nights is about 78, while the variance of maximum_nights 2789354050349 is extremely larger.

# %%
#Q2
reviews_df=pd.read_csv('/Users/carol/Desktop/reviews.csv') #read data from csv
reviews_df #show the data
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         1178162   4724140  2013-05-21      4298113       Olivier
# 1         1178162   4869189  2013-05-29      6452964     Charlotte
# 2         1178162   5003196  2013-06-06      6449554     Sebastian
# 3         1178162   5150351  2013-06-15      2215611        Marine
# 4         1178162   5171140  2013-06-16      6848427        Andrew
# ...           ...       ...         ...          ...           ...
# 68270     7462268  80537457  2016-06-18     22034145       Antonio
# 68271     7462268  83640094  2016-07-03     40052513         Steve
# 68272     7462268  85797088  2016-07-13     77129134          Nick
# 68273     7462268  97264637  2016-08-26     15799803           Vid
# 68274     7462268  98550693  2016-08-31     90128094       Arianna
#
#                                                 comments
# 0      My stay at islam's place was really cool! Good...
# ...

# %%
pip install nltk
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import nltk
nltk.download('punkt')
nltk.download('vader_lexicon')
#from textblob import TextBlob
import pandas as pd
import numpy as np
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk import tokenize

sentiment_analysis_columns = ['negativity', 'neutrality', 'positivity', 'compound']

file_names = [...]

sid = SentimentIntensityAnalyzer()

for i in range(len(file_names)):
    expanded_text_dataset = []
    file_name = file_names[i]
    print('Sentiment analysis for: %s' %file_name)
    file_df = reviews_df
    column_names = list(file_df.columns.values)
    all_columns = column_names + sentiment_analysis_columns
    text_segment_list = list(file_df['comments'])
    for j in range(len(text_segment_list)):
        row_info = list(file_df.iloc[j])
        text = text_segment_list[j]
        ##Sentiment analysis
        try:
            ss = sid.polarity_scores(text)
            negativity = ss['neg']
            neutrality = ss['neu']
            positivity = ss['pos']
            compound = ss['compound']
            temp_data = row_info + [negativity, neutrality, positivity, compound]
            expanded_text_dataset.append(temp_data)
        except:
            print('Sentiment analysis not done: ' + str(i) + ' / ' + str(len(file_df)))
            temp_data = row_info + ['NA', 'NA', 'NA', 'NA']
            expanded_text_dataset.append(temp_data)
    ##Storing the results in a dataset
    sentiment_dataset_df = pd.DataFrame(expanded_text_dataset, columns = all_columns)
    #sentiment_dataset_df.to_excel('%s_sentiment_analysis.xlsx' %file_name)
# Out:
# [nltk_data] Downloading package punkt to /Users/carol/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/carol/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Sentiment analysis for: Ellipsis
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# Sentiment analysis not done: 0 / 68275
# ...

# %%
reviews_df['negativity']=sentiment_dataset_df['negativity']
reviews_df['neutrality']=sentiment_dataset_df['neutrality']
reviews_df['positivity']=sentiment_dataset_df['positivity']
reviews_df['compound']=sentiment_dataset_df['compound']

# %%
reviews_df
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         1178162   4724140  2013-05-21      4298113       Olivier
# 1         1178162   4869189  2013-05-29      6452964     Charlotte
# 2         1178162   5003196  2013-06-06      6449554     Sebastian
# 3         1178162   5150351  2013-06-15      2215611        Marine
# 4         1178162   5171140  2013-06-16      6848427        Andrew
# ...           ...       ...         ...          ...           ...
# 68270     7462268  80537457  2016-06-18     22034145       Antonio
# 68271     7462268  83640094  2016-07-03     40052513         Steve
# 68272     7462268  85797088  2016-07-13     77129134          Nick
# 68273     7462268  97264637  2016-08-26     15799803           Vid
# 68274     7462268  98550693  2016-08-31     90128094       Arianna
#
#                                                 comments negativity  \
# 0      My stay at islam's place was really cool! Good...        0.0
# ...

# %%
import string
import re
positive_df=pd.read_csv('/Users/carol/Desktop/positive_words.csv', encoding='latin-1')
negative_df=pd.read_csv('/Users/carol/Desktop/negative_words.csv', encoding='latin-1')
positive_words = re.compile("|".join(positive_df['a+'].to_list()))
negative_words = re.compile("|".join(negative_df['2-faced'].to_list()).replace("*", ""))
reviews_df['comments']=reviews_df['comments'].apply(str)
reviews_df['comments']=reviews_df['comments'].apply(lambda s: s.lower().translate(str.maketrans('', '', string.punctuation)))

lengths = reviews_df['comments'].str.split().map(len)
positives = reviews_df['comments'].str.findall(positive_words).map(len)
positive_l=positives / lengths
negatives = reviews_df['comments'].str.findall(negative_words).map(len)
negative_l=negatives / lengths
reviews_df['total_number_words']=lengths
reviews_df['positivity_simple']=positive_l
reviews_df['negativity_simple']=negative_l
reviews_df
# Out:
#        listing_id        id        date  reviewer_id reviewer_name  \
# 0         1178162   4724140  2013-05-21      4298113       Olivier
# 1         1178162   4869189  2013-05-29      6452964     Charlotte
# 2         1178162   5003196  2013-06-06      6449554     Sebastian
# 3         1178162   5150351  2013-06-15      2215611        Marine
# 4         1178162   5171140  2013-06-16      6848427        Andrew
# ...           ...       ...         ...          ...           ...
# 68270     7462268  80537457  2016-06-18     22034145       Antonio
# 68271     7462268  83640094  2016-07-03     40052513         Steve
# 68272     7462268  85797088  2016-07-13     77129134          Nick
# 68273     7462268  97264637  2016-08-26     15799803           Vid
# 68274     7462268  98550693  2016-08-31     90128094       Arianna
#
#                                                 comments negativity  \
# 0      my stay at islams place was really cool good l...        0.0
# ...

# %%
#Q3
reviews_df['positivity_simple']=reviews_df['positivity_simple'].replace(np.nan, 0)
reviews_df['negativity_simple']=reviews_df['negativity_simple'].replace(np.nan, 0)
for i in range(len(reviews_df['negativity'])):
    if reviews_df['negativity'][i]=="NA":
        reviews_df['negativity'][i]=0
for i in range(len(reviews_df['positivity'])):
    if reviews_df['positivity'][i]=="NA":
        reviews_df['positivity'][i]=0
for i in range(len(reviews_df['neutrality'])):
    if reviews_df['neutrality'][i]=="NA":
        reviews_df['neutrality'][i]=0
for i in range(len(reviews_df['compound'])):
    if reviews_df['compound'][i]=="NA":
        reviews_df['compound'][i]=0
list_id=list(set(reviews_df['listing_id']))
len(list_id)
m=list(reviews_df['listing_id'])
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/224220385.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_df['negativity'][i]=0
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/224220385.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_df['positivity'][i]=0
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/224220385.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
listings_df['negativity_simple_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['negativity_simple_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['negativity_simple'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2172550447.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['negativity_simple_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['negativity_simple'].mean()

# %%
listings_df['positivity_simple_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['positivity_simple_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['positivity_simple'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/140385333.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['positivity_simple_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['positivity_simple'].mean()

# %%
listings_df['negativity_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['negativity_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['negativity'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2747625738.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['negativity_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['negativity'].mean()

# %%
listings_df['positivity_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['positivity_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['positivity'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2657282473.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['positivity_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['positivity'].mean()

# %%
listings_df['neutrality_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['neutrality_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['neutrality'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2084728846.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['neutrality_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['neutrality'].mean()

# %%
listings_df['compound_mean']=""
for r in range(len(list_id)):
    for x in range(len(listings_df['listing_id'])):
        if listings_df['listing_id'][x]==list_id[r]:
            listings_df['compound_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['compound'].mean()
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/430618123.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df['compound_mean'][x]=reviews_df[reviews_df['listing_id']==list_id[r]]['compound'].mean()

# %%
listings_df=listings_df.replace('', np.nan, regex=True)
listings_df
# Out:
#       listing_id                            listing_url     scrape_id  \
# 0       12147973  https://www.airbnb.com/rooms/12147973  2.020000e+13
# 1        3075044   https://www.airbnb.com/rooms/3075044  2.020000e+13
# 2           6976      https://www.airbnb.com/rooms/6976  2.020000e+13
# 3        1436513   https://www.airbnb.com/rooms/1436513  2.020000e+13
# 4        7651065   https://www.airbnb.com/rooms/7651065  2.020000e+13
# ...          ...                                    ...           ...
# 3580     8373729   https://www.airbnb.com/rooms/8373729  2.020000e+13
# 3581    14844274  https://www.airbnb.com/rooms/14844274  2.020000e+13
# 3582    14585486  https://www.airbnb.com/rooms/14585486  2.020000e+13
# 3583    14603878  https://www.airbnb.com/rooms/14603878  2.020000e+13
# 3584    14504422  https://www.airbnb.com/rooms/14504422  2.020000e+13
#
#      last_scraped                                           name  \
# ...

# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Q4
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
df_q4=listings_df[['property_type','room_type','accommodates','bathrooms','bedrooms']]
df_q4['accommodates'] = df_q4['accommodates'].astype(str)+' accommodates'
df_q4['bathrooms'] = df_q4['bathrooms'].astype(str)+' bathrooms'
df_q4['bedrooms'] = df_q4['bedrooms'].astype(str)+' bedrooms'
te = TransactionEncoder()
te_ary = te.fit(df_q4.values.astype(str)).transform(df_q4.values.astype(str))
df= pd.DataFrame(te_ary, columns=te.columns_)
# Out:
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2584257126.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_q4['accommodates'] = df_q4['accommodates'].astype(str)+' accommodates'
# /var/folders/0y/1xswhtb9233dmfpnjsyf9zb00000gn/T/ipykernel_44026/2584257126.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_q4['bathrooms'] = df_q4['bathrooms'].astype(str)+' bathrooms'
# ...

# %%
from mlxtend.frequent_patterns import apriori
print(apriori(df, min_support=0.1, use_colnames = True).sort_values(by=['support']))
# Out:
#      support                                        itemsets
# 46  0.100418  (Entire home/apt, 2.0 bedrooms, 1.0 bathrooms)
# 16  0.100418                   (2.0 bedrooms, 1.0 bathrooms)
# 30  0.101255                (Entire home/apt, 2.0 bathrooms)
# 38  0.102929    (1.0 bedrooms, Private room, 1 accommodates)
# 13  0.102929                  (Private room, 1 accommodates)
# ..       ...                                             ...
# 9   0.593305                               (Entire home/apt)
# 19  0.597768                      (Apartment, 1.0 bathrooms)
# 2   0.663598                                  (1.0 bedrooms)
# 8   0.728591                                     (Apartment)
# 1   0.767364                                 (1.0 bathrooms)
#
# [70 rows x 2 columns]

# %%
#when minSup is 0.1
#the top 5 most frequent itemsets are (1.0 bathrooms), (Apartment), (1.0 bedrooms), (Apartment, 1.0 bathrooms), (Entire home/apt)
#the top 5 least frequent itemsets are (1.0 bathrooms, Entire home/apt, 2.0 bedrooms), (1.0 bathrooms, 2.0 bedrooms), (Entire home/apt, 2.0 bathrooms), (1.0 bedrooms, 1 accommodates, Private room), (1 accommodates, Private room).

# %%
print(apriori(df, min_support=0.2, use_colnames = True).sort_values(by=['support']))
# Out:
#      support                                           itemsets
# 29  0.216179  (Apartment, 1.0 bedrooms, 2 accommodates, 1.0 ...
# 30  0.217573  (Apartment, 1.0 bedrooms, Entire home/apt, 1.0...
# 28  0.219247            (Apartment, 1.0 bedrooms, Private room)
# 18  0.219247                          (Apartment, Private room)
# 27  0.225105         (Apartment, 1.0 bedrooms, Entire home/apt)
# 25  0.233752          (Apartment, 1.0 bedrooms, 2 accommodates)
# 26  0.238494       (1.0 bedrooms, 2 accommodates, Private room)
# 16  0.238494                     (2 accommodates, Private room)
# 21  0.247141     (1.0 bedrooms, Entire home/apt, 1.0 bathrooms)
# 13  0.256904                    (1.0 bedrooms, Entire home/apt)
# 23  0.272245         (Apartment, 2 accommodates, 1.0 bathrooms)
# 15  0.290934                        (Apartment, 2 accommodates)
# 19  0.297908      (1.0 bedrooms, 2 accommodates, 1.0 bathrooms)
# 10  0.301813                      (Private room, 1.0 bathrooms)
# ...

# %%
print(apriori(df, min_support=0.2, use_colnames = True).sort_values(by=['support'])['itemsets'][29])
print(apriori(df, min_support=0.2, use_colnames = True).sort_values(by=['support'])['itemsets'][30])
# Out:
# frozenset({'Apartment', '1.0 bedrooms', '2 accommodates', '1.0 bathrooms'})
# frozenset({'Apartment', '1.0 bedrooms', 'Entire home/apt', '1.0 bathrooms'})

# %%
#when minSup is 0.2
#the top 5 most frequent itemsets are (1.0 bathrooms), (Apartment), (1.0 bedrooms), (Apartment, 1.0 bathrooms), (Entire home/apt)
#the top 5 least frequent itemsets are (1.0 bedrooms, Apartment, 1.0 bathrooms, 2 accommodates), (1.0 bedrooms, Apartment, 1.0 bathrooms, Entire home/apt), (1.0 bedrooms, Apartment, Private room), (Apartment, Private room), (1.0 bedrooms, Apartment, Entire home/apt). 
#I found under the minSup 0.1 and 0.2 have the same top 5 most frequent itemsets.

# %%
#Q5
# We firstly create the first candidate, 1 item for each candidate, and use frozensets to create a list for each unique item. Then, find the support counts of c1.
def create_c1(transactions):
    c1 = []
    c1_counts = {}
    for transaction in transactions:
        for item in transaction:
            item = frozenset([item]) # for each item in transaction, make it to a set
            if item not in c1:
                c1.append(item) # if item is not in c1 before, we add it to c1
            if item in c1_counts:
                c1_counts[item] += 1 # if itemset is already in the item count, then we add it's item count by 1
            else:
                c1_counts[item] = 1 # if itemset is not in the item count, then it's the first time we count it, so we set item count of this item to 1

    return c1, c1_counts

# Create frequent itemsets that pass the minSup
def create_freq_itemset(transactions, ck, minSup):
    itemset_count = {}
    nrows = len(transactions)  
# Go through the transaction and count the occurance of each item
    for transaction in transactions:
        for item in ck:
            if item.issubset(transaction):
                if item in itemset_count: 
                    itemset_count[item] += 1 # if itemset is already in the item count, then we add it's item count by 1
                else: 
                    itemset_count[item] = 1 # if itemset is not in the item count, then it's the first time we count it, so we set item count of this item to 1
   
    freq_itemset = []
    itemset_support = {}
                  
    for item in itemset_count:
        support = itemset_count[item] / nrows # calculate support of each item
        if support >= minSup:
            freq_itemset.append(item) # if the support of this item is greater than minSup, then it is a frequent item
            itemset_support[item] = support # for the frequent items, store their supports
    return freq_itemset, itemset_support

def create_ck(freq_k_transaction, k_next):
    ck = []
    k=len(freq_k_transaction)
    freq_set = [list(i) for i in freq_k_transaction]

    for i in range(0,k-1):
        for j in range(i + 1, k):
            for a in freq_set[j]:
                new_set = freq_set[i] + [a]
                if len(new_set) == k_next:
                    ck.append(new_set)
    return ck

def apriori(transactions, minSup, minConf):
    
    c1, c1_counts = create_c1(transactions) # create c1 and c1 counts
    freq_item, item_support_dict = create_freq_itemset(transactions, c1, minSup) # find frequent itemsets for c1 and their supports
    freq_items = [freq_item]
    
    k = 0
    while len(freq_items[k]) > 0:
        freq_item = freq_items[k]
        ck = create_ck(freq_item, k) #create ck      
        freq_item, item_support = create_freq_itemset(transactions, ck, minSup) # find frequent itemsets for ck and their supports
        freq_items.append(freq_item) # add frequent itemsets for ck to freq_item[]
        item_support_dict.update(item_support) # add their supports to item_support{}
        k = k + 1
        
    return freq_items, item_support_dict

# %%
datasettt = df_q4.values
print(apriori(datasettt, 0.1, 0))
# Out:
# ([[frozenset({'House'}), frozenset({'Entire home/apt'}), frozenset({'4 accommodates'}), frozenset({'2.0 bedrooms'}), frozenset({'Apartment'}), frozenset({'Private room'}), frozenset({'2 accommodates'}), frozenset({'1.0 bathrooms'}), frozenset({'1.0 bedrooms'}), frozenset({'3 accommodates'}), frozenset({'2.0 bathrooms'}), frozenset({'1 accommodates'})], []], {frozenset({'House'}): 0.15676429567642958, frozenset({'Entire home/apt'}): 0.5933054393305439, frozenset({'4 accommodates'}): 0.18131101813110181, frozenset({'2.0 bedrooms'}): 0.19330543933054392, frozenset({'Apartment'}): 0.7285913528591352, frozenset({'Private room'}): 0.38437935843793586, frozenset({'2 accommodates'}): 0.4136680613668061, frozenset({'1.0 bathrooms'}): 0.7673640167364016, frozenset({'1.0 bedrooms'}): 0.6635983263598326, frozenset({'3 accommodates'}): 0.1193863319386332, frozenset({'2.0 bathrooms'}): 0.13333333333333333, frozenset({'1 accommodates'}): 0.12245467224546723})

# %%
print(apriori(datasettt, 0.2, 0))
# Out:
# ([[frozenset({'Entire home/apt'}), frozenset({'Apartment'}), frozenset({'Private room'}), frozenset({'2 accommodates'}), frozenset({'1.0 bathrooms'}), frozenset({'1.0 bedrooms'})], []], {frozenset({'Entire home/apt'}): 0.5933054393305439, frozenset({'Apartment'}): 0.7285913528591352, frozenset({'Private room'}): 0.38437935843793586, frozenset({'2 accommodates'}): 0.4136680613668061, frozenset({'1.0 bathrooms'}): 0.7673640167364016, frozenset({'1.0 bedrooms'}): 0.6635983263598326})

# %%
#Compared with the corresponding value of support for each different frequent itemsets, we found the support we got is almost the same as the got in Q4.
#For instance, the Entire home/apt's support in Q4 with minSup 0.2 is 0.593305, in Q5 we got 0.5933054393305439. 
#Also, the 1.0 bathrooms's support in Q4 with minSup 0.1 is 0.767364, in Q5 we got 0.7673640167364016
#Thus, we got the same results as in Q4.

# %%
#Q6
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
listings_df1=listings_df.dropna(subset=['host_response_rate','review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','positivity_mean','negativity_mean','positivity_simple_mean', 'negativity_simple_mean'])
y=list(listings_df1['price'])
x1=list(listings_df1['host_response_rate'])
x2=list(listings_df1['review_scores_rating'])
x3=list(listings_df1['review_scores_accuracy'])
x4=list(listings_df1['review_scores_cleanliness'])
x5=list(listings_df1['review_scores_checkin'])
x6=list(listings_df1['review_scores_communication'])
x7=list(listings_df1['positivity_mean'])
x8=list(listings_df1['negativity_mean'])
x9=list(listings_df1['positivity_simple_mean'])
x10=list(listings_df1['negativity_simple_mean'])
X=np.column_stack((x1,x2,x3,x4,x5,x6,x7,x8,x9,x10))
X=sm.add_constant(X)
results = sm.OLS(y,X).fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     13.40
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           3.23e-23
# Time:                        21:51:36   Log-Likelihood:                -15507.
# No. Observations:                2543   AIC:                         3.104e+04
# Df Residuals:                    2532   BIC:                         3.110e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        116.1989     39.138      2.969      0.003      39.453     192.945
# ...

# %%
#The R-square is 0.05. According to to P-value in the chart and 5 percent confidence interval, we find the P- value of the coefficients of constant, review_scores_rating, review_scores_accuracy, review_scores_cleanliness, review_scores_checkin, positivity_simple_mean, and negativity_simple_mean are less than the the significance level 0.05. Thus, these coefficients are significant. This means the price y can be closely related to these variables.
#Effect size is a number measuring the strength of the relationship between two variables in a population, or a sample-based estimate of that quantity.

# %%
#Q7
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

pca = PCA(n_components = 3)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
explained_variance = pca.explained_variance_ratio_
X_train=sm.add_constant(X_train)
pca_results = sm.OLS(y_train,X_train).fit()
print(pca_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.271
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):             0.0784
# Time:                        21:51:44   Log-Likelihood:                -12415.
# No. Observations:                2034   AIC:                         2.484e+04
# Df Residuals:                    2030   BIC:                         2.486e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        166.7920      2.404     69.387      0.000     162.078     171.506
# ...

# %%
#As doing PCA, the standard errors of coefficients are generally smaller than before, which means the predictors are performs better in the model. 
#However, the R-square reduces a lot from 0.05 to 0.001, which means this model does not do well in predicting the price.

# %%
#Q8
#（i）
from matplotlib import pyplot as plt
below=0
above=0
for i in listings_df['compound_mean']:
    if i<0:
        below=below+1
    elif i>0:
        above=above+1
per_below=below/len(listings_df['compound_mean'])
abo_below=above/len(listings_df['compound_mean'])

compound = ['below','above']  
data = [per_below,abo_below] 
plt.bar(compound,data)
plt.title('The bar graph showing percentage of listings that have a compound_mean below zero and above zero')
plt.xlabel('compound mean')
plt.ylabel('The percentage of listings')
plt.show()

print('The percentage of listings that have a compound_mean below zero is', per_below)
print('The percentage of listings that have a compound_mean above zero is', abo_below)
# Out:
# The percentage of listings that have a compound_mean below zero is 0.00697350069735007
# The percentage of listings that have a compound_mean above zero is 0.7626220362622036

# %%
#(ii)
import seaborn as sns
import matplotlib.pyplot as plt
X_pca=pd.DataFrame(X)
sns.pairplot(X_pca)

# %%
#(iii)
Xtrain_pca=pd.DataFrame(X_train)
sns.pairplot(Xtrain_pca)

# %%
#(iv)
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     13.40
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):           3.23e-23
# Time:                        21:53:53   Log-Likelihood:                -15507.
# No. Observations:                2543   AIC:                         3.104e+04
# Df Residuals:                    2532   BIC:                         3.110e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        116.1989     39.138      2.969      0.003      39.453     192.945
# ...

# %%
myTable1 = PrettyTable(["Variables", "value"]) 
myTable1.add_row(["number of observations", 2543]) 
myTable1.add_row(["degrees of freedom", 10]) 
myTable1.add_row(["F-statistic", 13.4]) 
myTable1.add_row(["R^2 value", 0.05]) 
myTable1.add_row(["coefficient of constant", 116.1989]) 
myTable1.add_row(["coefficient of host_response_rate", -3.0095]) 
myTable1.add_row(["coefficient of review_scores_rating", 1.6745]) 
myTable1.add_row(["coefficient of review_scores_accuracy", -13.0994]) 
myTable1.add_row(["coefficient of review_scores_cleanliness", 16.4786]) 
myTable1.add_row(["coefficient of review_scores_checkin", -12.5665]) 
myTable1.add_row(["coefficient of review_scores_communication", -5.4678]) 
myTable1.add_row(["coefficient of positivity_mean", -34.0559]) 
myTable1.add_row(["coefficient of negativity_mean", -31.3040]) 
myTable1.add_row(["coefficient of positivity_simple_mean", 186.1752]) 
myTable1.add_row(["coefficient of negativity_simple_mean", 611.9750]) 
print(myTable1)
# Out:
# +--------------------------------------------+----------+
# |                 Variables                  |  value   |
# +--------------------------------------------+----------+
# |           number of observations           |   2543   |
# |             degrees of freedom             |    10    |
# |                F-statistic                 |   13.4   |
# |                 R^2 value                  |   0.05   |
# |          coefficient of constant           | 116.1989 |
# |     coefficient of host_response_rate      | -3.0095  |
# |    coefficient of review_scores_rating     |  1.6745  |
# |   coefficient of review_scores_accuracy    | -13.0994 |
# |  coefficient of review_scores_cleanliness  | 16.4786  |
# |    coefficient of review_scores_checkin    | -12.5665 |
# | coefficient of review_scores_communication | -5.4678  |
# |       coefficient of positivity_mean       | -34.0559 |
# |       coefficient of negativity_mean       | -31.304  |
# ...

# %%
#(v)
print(pca_results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     2.271
# Date:                Mon, 11 Oct 2021   Prob (F-statistic):             0.0784
# Time:                        22:02:27   Log-Likelihood:                -12415.
# No. Observations:                2034   AIC:                         2.484e+04
# Df Residuals:                    2030   BIC:                         2.486e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        166.7920      2.404     69.387      0.000     162.078     171.506
# ...

# %%
myTable2 = PrettyTable(["Variables", "value"]) 
myTable2.add_row(["number of observations", 2034]) 
myTable2.add_row(["degrees of freedom", 3]) 
myTable2.add_row(["F-statistic", 2.271]) 
myTable2.add_row(["R^2 value", 0.003]) 
myTable2.add_row(["coefficient of constant", 166.7920]) 
myTable2.add_row(["coefficient of host response rate", -2.6512]) 
myTable2.add_row(["coefficient of review scores", -0.5756]) 
myTable2.add_row(["coefficient of results of the sentiment analysis", 3.3390]) 
print(myTable2)
# Out:
# +--------------------------------------------------+---------+
# |                    Variables                     |  value  |
# +--------------------------------------------------+---------+
# |              number of observations              |   2034  |
# |                degrees of freedom                |    3    |
# |                   F-statistic                    |  2.271  |
# |                    R^2 value                     |  0.003  |
# |             coefficient of constant              | 166.792 |
# |        coefficient of host response rate         | -2.6512 |
# |           coefficient of review scores           | -0.5756 |
# | coefficient of results of the sentiment analysis |  3.339  |
# +--------------------------------------------------+---------+
